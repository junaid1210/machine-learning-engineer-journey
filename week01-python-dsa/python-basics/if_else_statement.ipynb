# %% [markdown]
# #if_else_statement

# %%
number=input("Enter the number: ")
number=int(number)

if number%2 == 0:
  print(number,"is evevn")
else:
  print(number,"is odd")
# Out:
# Enter the number: 223
# 223 is odd

# %%
pakistani=["biryani", "daal", "kheer"]
chinees=["fried rice", "pasta", "soup"]
italian=["sauce", "butter"]

cousine=input("Name the cousine? ")

if cousine in pakistani:
  print("the", cousine, "is pakistani")

elif cousine in chinees:
  print("the", cousine, "is chinees")

elif cousine in italian:
  print("the", cousine, "is italian")

else:
  print("i dont know which cousine is this")
# Out:
# Name the cousine? rabi
# i dont know which cousine is this

# %% [markdown]
# #Excercises

# %% [markdown]
# Exercise: Python If Condition
# 1. Using following list of cities per country,
#
#    india = ["mumbai", "banglore", "chennai", "delhi"]
#    pakistan = ["lahore","karachi","islamabad"]
#    bangladesh = ["dhaka", "khulna", "rangpur"]
#
# Write a program that asks user to enter a city name and it should tell which country the city belongs to

# %%
pakistan=["lahore","karachi","islamabad"]
india=["mumbai", "bangalore", "chennai"]
bangladesh=["dhaka", "khulna", "rangpur"]

count_name=input("Name any country: ")
if count_name in pakistan:
  print(count_name,"is the city of pakistan")
elif count_name in india:
  print(count_name, "is in indian")
elif count_name in bangladesh:
  print(count_name, "is in bangladesh")
else:
  print(count_name, "is not in any of the lists")
# Out:
# Name any country: quetta
# quetta is not in any of the lists

# %% [markdown]
# Exercise: Python If Condition
# 1. Using following list of cities per country,
#
#   india = ["mumbai", "banglore", "chennai", "delhi"]
#   pakistan = ["lahore","karachi","islamabad"]
#   bangladesh = ["dhaka", "khulna", "rangpur"]
#
# Write a program that asks user to enter two cities and it tells you if they both are in same country or not. For example if I enter mumbai and chennai, it will print "Both cities are in India" but if I enter mumbai and dhaka it should print "They don't belong to same country"

# %%
pakistan=["lahore","karachi","islamabad"]
india=["mumbai", "bangalore", "chennai"]
bangladesh=["dhaka", "khulna", "rangpur"]

city1=input("Enter city 1: ")
city2=input("Enter city 2: ")

if city1 and city2 in pakistan:
  print("both cities are from pakistan")
elif city1 and city2 in india:
  print("both cities from india")
elif city1 and city2 in bangladesh:
  print("both cities from bangladesh")
else:
  print(city1,"and", city2, "are not from the same country")
# Out:
# Enter city 1: mumbai
# Enter city 2: chennai
# both cities from india

# %%
pakistan=["lahore","karachi","islamabad"]
india=["mumbai", "bangalore", "chennai"]
bangladesh=["dhaka", "khulna", "rangpur"]

city1=input("Enter city 1: ")
city2=input("Enter city 2: ")

if city1 in pakistan and city2 in pakistan:
  print("both cities are from pakistan")
elif city1 in india and city2 in india:
  print("both cities from india")
elif city1 in bangladesh and city2 in bangladesh:
  print("both cities from bangladesh")
else:
  print(city1,"and", city2, "are not from the same country")
# Out:
# Enter city 1: mumbai
# Enter city 2: karachi
# mumbai and karachi are not from the same country

# %% [markdown]
# Exercise: Python If Condition
#  2. Write a python program that can tell you if your sugar is normal or not. Normal fasting level sugar range is 80 to 100.
#    1. Ask user to enter his fasting sugar level
#    2. If it is below 80 to 100 range then print that sugar is low
#    3. If it is above 100 then print that it is high otherwise print that it is normal

# %%
sugar_level=float(input("Enter your sugar level: "))
if sugar_level < 80:
  print("Your sugar level is low")
elif sugar_level > 100:
  print("Your sugar level is high")
else:
  print("your sugar level is normal")
# Out:
# Enter your sugar level: 85
# your sugar level is normal

# %% [markdown]
# Write a python programe that takes an interger input and prints whethr its positive, negative. (Considor 0 as positive)

# %%
number=int(input("Enter the number: "))

if number >= 0:
  print(f"{number} is Positive")
else:
  print(f"{number} is negative")
# Out:
# Enter the number: -10
# -10 is negative

# %% [markdown]
# Write a program that takes a character as input and prints whether
# it's a vowel or a consonant. (Multiple OR will be used)

# %%
chr=input("Enter an alphabet: ")

if chr == "a" or "e" or "i" or "o" or "u" or "A" or "E" or "I" or "O" or "U":
  print(f"{chr} is vowel")
else:
  print(f"{chr} is consonant")
# Out:
# Enter an alphabet: c
# c is vowel

# %%
chr = input("Enter an alphabet: ")

if chr in "aeiouAEIOU":
  print(f"{chr} is vowel")
else:
  print(f"{chr} is consonant")
# Out:
# Enter an alphabet: ae
# ae is vowel

# %% [markdown]
# A student will not be allowed to sit in exam if his/her attendance is
# less than 75%.
# Take following input from user
# Number of classes held
# Number of classes attended.
# 1. Print percentage of class attended
# 2. Print Is student is allowed to sit in exam or not.

# %%
total_classess=int(input("Enter total number of classe held: "))
classes_attended=int(input("Enter number of classes attended: "))

percentage_of_classes=(classes_attended/total_classess)*100

print(f"% of classes attended is: {percentage_of_classes}%")

if percentage_of_classes >= 75:
    print(f"You are not allowed to sit in the class")
else:
    print(f"You are allowed to sit in the class")
# Out:
# Enter total number of classe held: 100
# Enter number of classes attended: 80
# % of classes attended is: 80.0%
# You are allowed to sit in the class

# %% [markdown]
# Write a program to check if the number is ODD, EVEN or Equal to Zero.

# %%
number=int(input("Enter any number: "))

if number == 0:
  print("NUmber is equal to zero")
elif number%2 == 1:
  print(f"{number} is odd")
else:
  print(f"{number} is even")
# Out:
# Enter any number: 0
# NUmber is equal to zero

# %% [markdown]
# Write a program to check if number is divisible by 2 and 3 but not 8.

# %%
number=int(input("Enter the number: "))

if number%2 ==0 and number%3 == 0 and number%8 !=0:
  print(f"{number} is divisible by 2 and 3 and not by 8")
else:
  print("NO")
# Out:
# Enter the number: 24
# NO

# %% [markdown]
# Write a program to print the last digit of a number.

# %%
number=input("Enter the number: ")

print(number[-1])
# Out:
# Enter the number: 34445
# 5

# %%
number=int(input("Enter the number: "))

last_digit=number%10
print(last_digit)
# Out:
# Enter the number: 34567
# 7

# %% [markdown]
# Write a program to check if the last digit of a number is divisible by 5
# or not.

# %%
number=int(input("Enter the umber: "))

last_digit=number%10

print(f"Last digit is {last_digit}")

if last_digit%5 == 0:
  print(f"{last_digit} is divisible by 5")
else:
  print(f"{last_digit} is not divisible by 5")
# Out:
# Enter the umber: 245
# Last digit is 5
# 5 is divisible by 5

# %% [markdown]
# Write a program to calculate bill. Ask the final amount from the user.
# You have to give discount and print the final bill after discount.
#
# 50000 above - 30% discount
#
# 40000 - 49999 - 25% discount
#
# 30000 - 39999 - 20% discount
#
# 10000 - 29999 - 10% discount
#
# 1 - 9999 - No discount
#
# Print the discount and the final amount to be paid.

# %%
final_amount=int(input("Enter the final bill amount: "))

if final_amount >= 50000:
  print("You got 30% discount")
  print("Your bill after discount is", (final_amount/100)*70)

elif final_amount >= 40000 and final_amount < 50000:
  print("You got 25% discount")
  print("Your bill after discount is", (final_amount/100)*75)

elif final_amount >= 30000 and final_amount <= 40000:
  print(("You got 20% discount"))
  print("Your bill after discount is", (final_amount/100)*80)

elif final_amount >= 10000 and final_amount < 30000:
  print("You got 10% discount")
  print("Your bill after discount is", (final_amount/100)*90)

else:
  print("No discount")
# Out:
# Enter the final bill amount: 4000
# No discount

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ask 4 numbers from user. Make sure all the numbers entered by user
# are different. Print which number is the smallest.

# %%
num1=int(input("Enter first number: "))
num2=int(input("Enter second number: "))
num3=int(input("Enter third number: "))
num4=int(input("Enter fourth number: "))

if num1==num2 or num1==num3 or num1==num4 or num2==num3 or num2==num4 or num3==num4:
  print("Numbers entered are not different, enter numbers again")
elif num1<num2 and num1 < num3 and num1 < num4:
  print(f"num1 is the smallest")
elif num2<num1 and num2<num3 and num2<num4:
  print(f"num2 is the smallest")
elif num3<num1 and num3<num2 and num3<num4:
  print(f"num3 is the smallest")
else:
  print(f"num4 is the smallest")
# Out:
# Enter first number: 4
# Enter second number: 5
# Enter third number: 6
# Enter fourth number: 7
# num1 is the smallest

# %% [markdown]
# Ask a number from user.
#
# Print “Fizz” if the number is divisible by 3.
#
# Print “Buzz” if the number is divisible by 5.
#
# Print “FizzBuzz” if the number is divisible by 3 and 5.
#
# Print the number itself if none of the conditions are true.

# %%
number=int(input("Enter the number: "))
if number % 3 == 0 and number % 5 == 0:
  print("FizzBuzz")
elif number % 3 == 0:
  print("Fizz")
elif number % 5 == 0:
  print("Buzz")
else:
  print(number)
# Out:
# Enter the number: 15
# FizzBuzz

# %% [markdown]
# Take Salary as input from User and Update the salary of an employee.
#
# salary less than 10,000, 5 % increment
#
# salary between 10,000 and 20, 000, 10 % increment
#
# salary between 20,000 and 50,000, 15 % increment
#
# salary more than 50,000, 20 % increment

# %%
salary=int(input("Enter the salary: "))

if salary < 10000:
  increment = 20
elif salary >= 10000 and salary < 20000:
  increment = 15
elif salary >= 20000 and salary < 50000:
  increment = 10
elif salary > 50000:
  increment = 5
else:
  print("No increment")

new_salary = salary + (salary/100)*increment
print(f"New salari is {new_salary}")
# Out:
# Enter the salary: 60000
# New salari is 63000.0
